# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeshkumar170201/Machine-Learning/blob/main/Scrapping_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scrapping**

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.goodreads.com/quotes/tag/love?page={}"

# %%
emotions = ["love", "life"]

# %%
url.format("love")
# Out:
# 'https://www.goodreads.com/quotes/tag/love?page=love'

# %%
def get_quotes(url): 

  res = requests.get(url)

  soup = BeautifulSoup(res.text)

  quote_divs = soup.find_all("div", attrs={"class":"quote"})

  quotes = []

  for quote_div in quote_divs:

    quoteText_div = quote_div.find_next("div", attrs={"class":"quoteText"})
    
    striped = quoteText_div.text.strip()
    
    striped_li = striped.split("\n")
    
    quote = striped_li[0][1:-1]
    
    author = striped_li[-1].strip()

    left_div = quote_div.find_next("div", attrs={"class" : "left"})
    tags = [tag.text for tag in  left_div.find_all("a")]

    quote_item = {
        "text" : quote,
        "author" : author,
        "tags" : tags
    }
    quotes.append(quote_item)
    
  return quotes

# %% [markdown]
# You can add whole list using append while using append you can add only one item

# %%
total = []
for i in range(1, 6):
  total.extend(get_quotes(url.format("love", i)))
  print("processed", i)
# Out:
# processed 1
# processed 2
# processed 3
# processed 4
# processed 5

# %%
len(total)
# Out:
# 150

# %%
total
# Out:
# [{'author': 'Marilyn Monroe',
#   'tags': ['attributed-no-source',
#    'best',
#    'life',
#    'love',
#    'mistakes',
#    'out-of-control',
#    'truth',
#    'worst'],
#   'text': "I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best."},
#  {'author': 'William W. Purkey',
#   'tags': ['dance', 'heaven', 'hurt', 'inspirational', 'life', 'love', 'sing'],
#   'text': "You've gotta dance like there's nobody watching,Love like you'll never be hurt,Sing like there's nobody listening,And live like it's heaven on earth."},
#  {'author': 'Dr. Seuss',
#   'tags': ['attributed-no-source', 'dreams', 'love', 'reality', 'sleep'],
#   'text': "You know you're in love when you can't fall asleep because reality is finally better than your dreams."},
#  {'author': 'Elbert Hubbard',
#   'tags': ['friend', 'friendship', 'knowledge', 'love'],
# ...

# %% [markdown]
# **PANDAS**

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
names = ["Anuj", "Ravi", "Mohit"]

# %%
ages = [26, 34, 21]

# %%
d = {
    "name" : names,
     "age" : ages
}

# %%
d
# Out:
# {'age': [26, 34, 21], 'name': ['Anuj', 'Ravi', 'Mohit']}

# %%
pd.DataFrame(d)
# Out:
#     name  age
# 0   Anuj   26
# 1   Ravi   34
# 2  Mohit   21

# %%
import numpy as np

# %%
data = np.random.randint(10, 20, (10, 5))

# %%
pd.DataFrame(data)
# Out:
#     0   1   2   3   4
# 0  13  13  11  10  11
# 1  17  12  12  11  16
# 2  13  17  12  10  14
# 3  15  15  17  16  15
# 4  19  13  11  12  15
# 5  11  12  16  14  15
# 6  15  17  11  14  10
# 7  15  13  11  16  17
# 8  18  13  11  17  14
# 9  15  19  10  13  19

# %%
pd.DataFrame(data, columns=["p", "c", "m", "e", "b"])
# Out:
#     p   c   m   e   b
# 0  13  13  11  10  11
# 1  17  12  12  11  16
# 2  13  17  12  10  14
# 3  15  15  17  16  15
# 4  19  13  11  12  15
# 5  11  12  16  14  15
# 6  15  17  11  14  10
# 7  15  13  11  16  17
# 8  18  13  11  17  14
# 9  15  19  10  13  19

# %%
marks = pd.DataFrame(data, columns=["p", "c", "m", "e", "b"])

# %%
marks["cs"] = 0

# %%
marks
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 1  17  12  12  11  16   0
# 2  13  17  12  10  14   0
# 3  15  15  17  16  15   0
# 4  19  13  11  12  15   0
# 5  11  12  16  14  15   0
# 6  15  17  11  14  10   0
# 7  15  13  11  16  17   0
# 8  18  13  11  17  14   0
# 9  15  19  10  13  19   0

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.T
# Out:
#                  0       1       2    ...        147        148        149
# sepal_length     5.1     4.9     4.7  ...        6.5        6.2        5.9
# sepal_width      3.5       3     3.2  ...          3        3.4          3
# petal_length     1.4     1.4     1.3  ...        5.2        5.4        5.1
# petal_width      0.2     0.2     0.2  ...          2        2.3        1.8
# species       setosa  setosa  setosa  ...  virginica  virginica  virginica
#
# [5 rows x 150 columns]

# %%
df.sort_index?

# %%
marks.sort_index(axis=1)
# Out:
#     b   c  cs   e   m   p
# 0  11  13   0  10  11  13
# 1  16  12   0  11  12  17
# 2  14  17   0  10  12  13
# 3  15  15   0  16  17  15
# 4  15  13   0  12  11  19
# 5  15  12   0  14  16  11
# 6  10  17   0  14  11  15
# 7  17  13   0  16  11  15
# 8  14  13   0  17  11  18
# 9  19  19   0  13  10  15

# %%
marks.sort_values?

# %%
marks.sort_values(["e"])
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 2  13  17  12  10  14   0
# 1  17  12  12  11  16   0
# 4  19  13  11  12  15   0
# 9  15  19  10  13  19   0
# 5  11  12  16  14  15   0
# 6  15  17  11  14  10   0
# 3  15  15  17  16  15   0
# 7  15  13  11  16  17   0
# 8  18  13  11  17  14   0

# %%
marks.iloc[:5, 1:3]
# Out:
#     c   m
# 0  13  11
# 1  12  12
# 2  17  12
# 3  15  17
# 4  13  11

# %% [markdown]
# *** Slicing***

# %%
marks.iloc[:5]
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 1  17  12  12  11  16   0
# 2  13  17  12  10  14   0
# 3  15  15  17  16  15   0
# 4  19  13  11  12  15   0

# %%
marks.iloc[:5, 1:]
# Out:
#     c   m   e   b  cs
# 0  13  11  10  11   0
# 1  12  12  11  16   0
# 2  17  12  10  14   0
# 3  15  17  16  15   0
# 4  13  11  12  15   0

# %%
marks.iloc[::2]
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 2  13  17  12  10  14   0
# 4  19  13  11  12  15   0
# 6  15  17  11  14  10   0
# 8  18  13  11  17  14   0

# %%
marks.iloc[0:10:2]
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 2  13  17  12  10  14   0
# 4  19  13  11  12  15   0
# 6  15  17  11  14  10   0
# 8  18  13  11  17  14   0

# %%
marks.iloc[[0, 2, 6]]
# Out:
#     p   c   m   e   b  cs
# 0  13  13  11  10  11   0
# 2  13  17  12  10  14   0
# 6  15  17  11  14  10   0

# %%
marks.iloc[[0, 2, 6], [0, 2, 3]]
# Out:
#     p   m   e
# 0  13  11  10
# 2  13  12  10
# 6  15  11  14

# %% [markdown]
# **Data -> DataFrames -> CSV**

# %%
import pandas as pd

# %%
pd.DataFrame(total)
# Out:
#                                                   text  ...                                               tags
# 0    I'm selfish, impatient and a little insecure. ...  ...  [attributed-no-source, best, life, love, mista...
# 1    You've gotta dance like there's nobody watchin...  ...  [dance, heaven, hurt, inspirational, life, lov...
# 2    You know you're in love when you can't fall as...  ...  [attributed-no-source, dreams, love, reality, ...
# 3    A friend is someone who knows all about you an...  ...              [friend, friendship, knowledge, love]
# 4    Darkness cannot drive out darkness: only light...  ...  [darkness, drive-out, hate, inspirational, lig...
# ..                                                 ...  ...                                                ...
# 145  You don't love someone because they're perfect...  ...                                  [imperfect, love]
# ...

# %%
df = pd.DataFrame(total)

# %%
df.to_csv("scrap.csv")

# %%
df.to_csv("scrap.csv", index=None)
